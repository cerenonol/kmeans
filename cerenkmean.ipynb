# %% [markdown]
# <a href="https://colab.research.google.com/github/cerenonol/kmeans/blob/main/cerenkmean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

data = {
    'Ülke': ['Almanya', 'İspanya', 'Hollanda', 'Danimarka', 'Belçika',
             'İtalya', 'İsviçre', 'İrlanda', 'Fransa', 'Portekiz',
             'Türkiye', 'İran', 'Kırgızistan', 'Tanzanya', 'Polonya',
             'İsveç', 'Çek', 'Brezilya', 'Meksika', 'Rusya'],
    'Haftalık_Ortalama_Saatler': [34, 36, 34, 34, 34,
                                   36, 36, 36, 36, 36,
                                   44, 46, 40, 44, 39,
                                   36,38,42,35,34],
    'Refah_Düzeyi': [6892, 6436, 6892, 7586, 6859,
                     6405, 7240, 6911, 6661, 5968,
                     4614, 4876, 5825, 3694, 6260,
                     2276,6845,5466,7804,7315],
    'Kişi_Başına_Gelir': [52722, 33071, 62719, 68300, 53659,
                          38326, 100413, 104272, 46001, 27880,
                          12849, 4663, 1843, 1254, 21996,
                          56225,30600,15854,54008,87739]
}

df = pd.DataFrame(data)

X = df[['Haftalık_Ortalama_Saatler', 'Refah_Düzeyi']]
y = df['Kişi_Başına_Gelir']

model = LinearRegression()
model.fit(X, y)

tahminler = model.predict(X)
mse = np.mean((y - tahminler) ** 2)
print(f'Ortalama Kare Hatası: {mse}')

kmeans = KMeans(n_clusters=3, random_state=42)
df['Küme'] = kmeans.fit_predict(X)

silhouette_avg = silhouette_score(X, df['Küme'])
print(f'Silhouette Skoru: {silhouette_avg}')

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x=df['Haftalık_Ortalama_Saatler'], y=df['Kişi_Başına_Gelir'], color='blue', label='Gerçek Değerler')
plt.plot(df['Haftalık_Ortalama_Saatler'], tahminler, color='red', label='Regresyon Hattı')
plt.title('Kişi Başına Gelir - Haftalık Ortalama Saatler')
plt.xlabel('Haftalık Ortalama Saatler')
plt.ylabel('Kişi Başına Gelir')
plt.legend()

plt.subplot(1, 2, 2)
sns.scatterplot(x='Haftalık_Ortalama_Saatler', y='Kişi_Başına_Gelir', hue='Küme', data=df, palette='deep')
plt.title('K-Means Kümeleme')
plt.xlabel('Haftalık Ortalama Saatler')
plt.ylabel('Kişi Başına Gelir')


plt.tight_layout()
plt.show()
# Out:
# Ortalama Kare Hatası: 405724856.3362962
# Silhouette Skoru: 0.5640542156823606

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

data = {
    'Ülke': ['Almanya', 'İspanya', 'Hollanda', 'Danimarka', 'Belçika',
             'İtalya', 'İsviçre', 'İrlanda', 'Fransa', 'Portekiz',
             'Türkiye', 'İran', 'Kırgızistan', 'Tanzanya', 'Polonya',
             'İsveç', 'Çek', 'Brezilya', 'Meksika', 'Rusya'],
    'Haftalık_Ortalama_Saatler': [34, 36, 34, 34, 34,
                                   36, 36, 36, 36, 36,
                                   44, 46, 40, 44, 39,
                                   36,38,42,35,34],
    'Refah_Düzeyi': [6892, 6436, 6892, 7586, 6859,
                     6405, 7240, 6911, 6661, 5968,
                     4614, 4876, 5825, 3694, 6260,
                     2276,6845,5466,7804,7315],
    'Kişi_Başına_Gelir': [52722, 33071, 62719, 68300, 53659,
                          38326, 100413, 104272, 46001, 27880,
                          12849, 4663, 1843, 1254, 21996,
                          56225,30600,15854,54008,87739]
}

df = pd.DataFrame(data)

X = df[['Haftalık_Ortalama_Saatler', 'Refah_Düzeyi']]
y = df['Kişi_Başına_Gelir']

model = LinearRegression()
model.fit(X, y)

tahminler = model.predict(X)
mse = np.mean((y - tahminler) ** 2)
print(f'Ortalama Kare Hatası: {mse}')

kmeans = KMeans(n_clusters=3, random_state=42)
df['Küme'] = kmeans.fit_predict(X)

silhouette_avg = silhouette_score(X, df['Küme'])
print(f'Silhouette Skoru: {silhouette_avg}')

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.scatterplot(x=df['Haftalık_Ortalama_Saatler'], y=df['Kişi_Başına_Gelir'], color='blue', label='Gerçek Değerler')
plt.plot(df['Haftalık_Ortalama_Saatler'], tahminler, color='red', label='Regresyon Hattı')
plt.title('Kişi Başına Gelir - Haftalık Ortalama Saatler')
plt.xlabel('Haftalık Ortalama Saatler')
plt.ylabel('Kişi Başına Gelir')
plt.legend()

plt.subplot(1, 2, 2)
sns.scatterplot(x='Haftalık_Ortalama_Saatler', y='Kişi_Başına_Gelir', hue='Küme', data=df, palette='deep')
plt.title('K-Means Kümeleme')
plt.xlabel('Haftalık Ortalama Saatler')
plt.ylabel('Kişi Başına Gelir')


plt.tight_layout()
plt.show()
# Out:
# Ortalama Kare Hatası: 405724856.3362962
# Silhouette Skoru: 0.5640542156823606
